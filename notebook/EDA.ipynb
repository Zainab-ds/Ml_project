# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plyt 
#import warning 
#warning.filterwarnings('ignore')

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\User\Ml_project\venv\python.exe
